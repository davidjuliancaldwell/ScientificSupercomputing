# %%
import coinflip as cfm

# %matplotlib inline

# %% [markdown]
# ### Part a

# %%
cfm.coinflip_func(0.2,1000,5000)
# Out:
# The mean number of heads is 199.9818, the variance of the number of heads is 160.78146876
# (199.98179999999999, 160.78146876)

# %% [markdown]
# ### Part b

# %%
p = 0.3
N = [8,16,32,64]
M = 10000

[cfm.coinflip_func(0.3,x,M) for x in N]
# Out:
# The mean number of heads is 2.3917, the variance of the number of heads is 1.65987111
# The mean number of heads is 4.7654, the variance of the number of heads is 3.3225628399999994
# The mean number of heads is 9.6519, the variance of the number of heads is 6.81872639
# The mean number of heads is 19.1845, the variance of the number of heads is 13.382859750000003
# [(2.3917000000000002, 1.6598711100000001),
#  (4.7653999999999996, 3.3225628399999994),
#  (9.6518999999999995, 6.8187263900000001),
#  (19.1845, 13.382859750000003)]

# %%
p = 0.03
N = [10,100,1000,10000]
M = 1000

[cfm.coinflip_func(0.3,x,M) for x in N]
# Out:
# The mean number of heads is 2.944, the variance of the number of heads is 2.156864
# The mean number of heads is 29.663, the variance of the number of heads is 19.909431
# The mean number of heads is 300.348, the variance of the number of heads is 222.818896
# The mean number of heads is 2999.294, the variance of the number of heads is 2059.5135640000003
# [(2.944, 2.1568640000000001),
#  (29.663, 19.909431000000001),
#  (300.34800000000001, 222.818896),
#  (2999.2939999999999, 2059.5135640000003)]
